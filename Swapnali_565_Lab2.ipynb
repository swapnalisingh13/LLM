# %% [markdown]
# <a href="https://colab.research.google.com/github/swapnalisingh13/LLM/blob/main/Swapnali_565_Lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install python-dotenv
# !pip install langchain
# !pip install langchain-groq
# Out:
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (1.0.1)
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (0.2.7)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.12 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.2.13)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.2.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.1.85)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.25.2)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.8.0)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (8.4.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.12->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.12->langchain) (24.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.6)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (2.20.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2024.6.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.12->langchain) (3.0.0)
# Requirement already satisfied: langchain-groq in /usr/local/lib/python3.10/dist-packages (0.1.6)
# Requirement already satisfied: groq<1,>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from langchain-groq) (0.9.0)
# Requirement already satisfied: langchain-core<0.3,>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from langchain-groq) (0.2.13)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain-groq) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from groq<1,>=0.4.1->langchain-groq) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain-groq) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain-groq) (2.8.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain-groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain-groq) (4.12.2)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.2.2->langchain-groq) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.2.2->langchain-groq) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.2.2->langchain-groq) (0.1.85)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.2.2->langchain-groq) (24.1)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.2.2->langchain-groq) (8.4.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain-groq) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain-groq) (1.2.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.2.2->langchain-groq) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.2->langchain-groq) (3.10.6)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.2->langchain-groq) (2.31.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (2.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.2->langchain-groq) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.2->langchain-groq) (2.0.7)

# %%
from dotenv import load_dotenv
from langchain.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_groq import ChatGroq
import os

# %%
load_dotenv()

# Retrieve the API key from the environment variable
api_key = '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'
# Print the API key to ensure it is loaded correctly (for debugging purposes, remove this in production)
print(api_key)
# Out:
# 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

# %%
model = ChatGroq(api_key = api_key ,model_name = 'gemma2-9b-it')

# %%
parser = StrOutputParser()
chain = model | parser
chain.invoke('what is fountain')
# Out:
# "A fountain is a structure that projects water into the air and sometimes collects it again in a basin or pool. \n\nHere's a breakdown of what makes a fountain:\n\n* **Water Source:** Fountains need a source of water, which can be a pump drawing from a well, reservoir, or city water supply.\n* **Pump:**  A pump is essential to push the water upwards against gravity.\n* **Nozzles:**  Nozzles control the shape and direction of the water flow. They can create a variety of effects, from simple sprays to elaborate arcs and patterns.\n* **Basin or Pool:** Many fountains have a basin or pool at the base to catch the falling water. This can add to the visual appeal and create a calming sound.\n\n**Types of Fountains:**\n\n* **Architectural Fountains:** These are often large, elaborate structures that are part of a building or public space.\n* **Decorative Fountains:** These are smaller fountains that are used to add beauty to gardens, patios, or homes.\n* **Water Features:** This is a broader term that encompasses any structure that features moving water, including fountains, waterfalls, and ponds.\n\n**The purpose of a fountain can vary:**\n\n* **Ornamental:**  To add beauty and visual interest to a space.\n* **Functional:**  To provide a source of water for drinking or irrigation.\n* **Symbolic:**  To represent purity, abundance, or other concepts.\n* **Therapeutic:**  The sound of flowing water can be calming and relaxing.\n\n\nLet me know if you have any other questions about fountains!\n\n"

# %% [markdown]
# Question Answering

# %%
template = (
    """
    you're question answering expert
answer : {answer}
"""
)

# %%
prompt = PromptTemplate.from_template(template=template)

# %%
chain =  prompt | model | parser

# %%
answer = """
tell me about samosa
"""

# %%
result = chain.invoke({'answer':answer})
print(result)
# Out:
# ## Let's talk Samosas!
#
# Samosas are delicious fried or baked pastries with a savory filling. They are incredibly popular in South Asia and have spread worldwide, enjoyed as street food, appetizers, or even part of a main meal.
#
# Here's a breakdown:
#
# **The Basics:**
#
# * **Shape:**  Typically triangular or cone-shaped, but can also be found in other forms.
# * **Dough:** Made from a flaky pastry dough, usually a combination of wheat flour and water.
# * **Filling:**  The heart of the samosa! Common fillings include:
#     * **Potatoes & Peas:** A classic combination spiced with cumin, coriander, turmeric, and chili.
#     * **Lentils:**  A hearty and flavorful option, often spiced with garam masala and ginger.
#     * **Meat:**  Beef, lamb, chicken, or even fish can be used, cooked with a variety of spices and herbs.
#     * **Paneer:**  Indian cheese adds a creamy texture and tangy flavor.
# * **Preparation:** The filling is cooked separately, then encased in the pastry dough and deep-fried or baked until golden brown and crispy.
#
# **Serving:**
#
# * **Accompaniments:**  Samosas are often served with chutney (a sweet or spicy condiment), yogurt, or tamarind sauce.
# * **Variety:**  There are countless regional variations of samosas, each with its own unique flavor profile and fillings.
#
# **Fun Facts:**
#
# * Samosas are thought to have originated in the Middle East and spread to India through trade routes.
# * They are a popular snack during festivals and celebrations.
# * Samosa chaat, a popular street food dish, combines samosas with various toppings like chickpeas, yogurt, and chutneys.
#
#
# Let me know if you have any other questions about samosas!

# %%
model = ChatGroq(api_key = api_key ,model_name = 'llama3-8b-8192')
parser = StrOutputParser()
chain = model | parser
chain.invoke('what is fountain')
# Out:
# 'A fountain is a structure that releases water into the air, often in a decorative or artistic manner. Fountains can be found in a variety of settings, including:\n\n1. Public spaces: Parks, squares, and streets often feature fountains as a source of beauty and relaxation.\n2. Gardens and courtyards: Fountains can be a focal point in a garden or courtyard, adding visual interest and creating a sense of tranquility.\n3. Buildings and architecture: Fountains can be incorporated into the design of buildings, such as hotels, museums, and monuments.\n4. Private homes: Many people install fountains in their backyards or gardens to create a peaceful and serene atmosphere.\n\nTypes of fountains:\n\n1. Jet fountain: A fountain that shoots water high into the air, often in a circular motion.\n2. Basin fountain: A fountain that collects water in a basin or pool, often with a decorative rim.\n3. Wall fountain: A fountain that is mounted on a wall and sprays water down or outward.\n4. Pool fountain: A fountain that is installed in a pool or pond, often with a decorative feature such as a statue or cascade.\n5. Misting fountain: A fountain that creates a fine mist or fog, often used in warm climates to cool the air.\n\nFountains can be powered by various sources, including:\n\n1. Gravity: Water flows from a higher point to a lower point, creating a natural flow.\n2. Pumps: Electric or mechanical pumps are used to circulate water and create movement.\n3. Wind: Natural wind can be used to power a fountain, often in combination with other sources.\n\nFountains have a long history, dating back to ancient civilizations such as the Egyptians, Greeks, and Romans. Today, they remain a popular feature in many different cultures and settings.'

# %%
model = ChatGroq(api_key = api_key ,model_name = 'llama3-8b-8192')
parser = StrOutputParser()
chain = model | parser
chain.invoke('what is fountain')
# Out:
# 'A fountain can refer to several things, depending on the context:\n\n1. **Water fountain**: A device that dispenses water, often in a decorative or artistic way. It can be a standalone structure or integrated into a larger design, such as a park, garden, or architecture. Water fountains can be powered by gravity, electricity, or other means.\n2. **Fountain pen**: A type of pen that uses a refillable ink reservoir and a mechanism to deliver ink to the nib, allowing for a consistent and precise writing experience.\n3. **Fountain of youth**: A mythical concept, often associated with alchemy or mysticism, that is believed to grant eternal youth, beauty, or vitality. This idea has been depicted in literature, art, and popular culture throughout history.\n4. **Fountain of knowledge**: A metaphorical concept that represents a source of wisdom, understanding, or insight. This can be a person, a book, a website, or a institution that provides information and knowledge.\n5. **Fountain (music)**: In music, a fountain can refer to a musical composition or a section within a larger work that features a flowing, improvisational structure, often with a sense of continuity and spontaneity.\n6. **Fountain (architecture)**: In architecture, a fountain can be a decorative element, such as a basin or a spout, that is integrated into a building or a monument.\n7. **Fountain (mythology)**: In mythology, a fountain can be a sacred or magical spring, often associated with gods, goddesses, or other supernatural beings.\n\nThese are just a few examples of what a fountain can be. The term can have different meanings depending on the context and cultural background.'

# %% [markdown]
# From Gemini

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# From Chatgpt

# %% [markdown]
# ![image.png](data:image/png;base64,...)
